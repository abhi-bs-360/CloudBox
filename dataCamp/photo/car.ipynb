# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

print('ok done')
# Out:
# ok done

# %%
plate_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_plate_number.xml')

# %%
img = cv2.imread('cars.jpg')
fixed = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fixed)

# %%
plate_rects = plate_classifier.detectMultiScale(fixed, 1.5, 0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-13-5d4efe5cacea> in <module>
# ----> 1 plate_rects = plate_classifier.detectMultiScale(fixed, 1.5, 0)
#
# error: OpenCV(4.3.0) C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'
